# %%
library("igraph")
# Out:
# Warning message:
# "package 'igraph' was built under R version 3.5.3"
# Attaching package: 'igraph'
#
# The following objects are masked from 'package:stats':
#
#     decompose, spectrum
#
# The following object is masked from 'package:base':
#
#     union

# %%
dat = read.csv('gcc.csv', header=TRUE)

# %%
g <- graph.data.frame(dat)
layout_g = layout_nicely(g)

# %%
plot(g, edge.arrow.size=.01, vertex.size=3, vertex.label="", layout = layout_g)
# Out:
# Plot with title ""
